# %%
# Out:
# 4

# %%
import pandas as pd

df = pd.read_csv("D:\Ineuron Notes\Sudh\pandas\FitBit data.csv")
print(df.columns)
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
df1 = pd.read_csv("D:\Ineuron Notes\Sudh\pandas\FitBit data.csv")

# %%
df1.to_csv("D:/df111.txt")

# %%
df1.to_csv("textttt.txt")

# %%
df1.to_csv("D:/Faisal/excellll.xlsx")

# %%
df1.to_csv("D:/Faisal/excelll1l.xls")

# %%
(df.Id.unique())
# Out:
# array([1503960366, 1624580081, 1644430081, 1844505072, 1927972279,
#        2022484408, 2026352035, 2320127002, 2347167796, 2873212765,
#        2891001357, 3372868164, 3977333714, 4020332650, 4057192912,
#        4319703577, 4388161847, 4445114986, 4558609924, 4702921684,
#        5553957443, 5577150313, 6117666160, 6290855005, 6391747486,
#        6775888955, 6962181067, 7007744171, 7086361926, 8053475328,
#        8253242879, 8378563200, 8583815059, 8792009665, 8877689391],
#       dtype=int64)

# %%
len(df.Id)
# Out:
# 457

# %%
df.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
df
# Out:
#             Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    27.530001    3/25/2016       11004       7.110000         7.110000
# 1    27.530001    3/26/2016       17609      11.550000        11.550000
# 2    27.530001    3/27/2016       12736       8.530000         8.530000
# 3    27.530001    3/28/2016       13231       8.930000         8.930000
# 4    27.530001    3/29/2016       12041       7.850000         7.850000
# ..         ...          ...         ...            ...              ...
# 452  27.530001     4/8/2016       23014      20.389999        20.389999
# 453  27.530001     4/9/2016       16470       8.070000         8.070000
# 454  27.530001    4/10/2016       28497      27.530001        27.530001
# 455  27.530001    4/11/2016       10622       8.060000         8.060000
# 456  27.530001    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
"""3. convert all the dates avaible in dataset to timestamp format in pandas 
and in sql you to convert it in date format"""


x = pd.to_datetime(df["ActivityDate"])

# %%
x
# Out:
# 0     2016-03-25
# 1     2016-03-26
# 2     2016-03-27
# 3     2016-03-28
# 4     2016-03-29
#          ...
# 452   2016-04-08
# 453   2016-04-09
# 454   2016-04-10
# 455   2016-04-11
# 456   2016-04-12
# Name: ActivityDate, Length: 457, dtype: datetime64[ns]

# %%
pd.Timestamp("2016-04-08")
# Out:
# Timestamp('2016-04-08 00:00:00')

# %%
pd.to_datetime("2016-04-12")
# Out:
# Timestamp('2016-04-12 00:00:00')

# %% [markdown]
# x.apply()

# %%
x.apply(pd.Timestamp)
# Out:
# 0     2016-03-25
# 1     2016-03-26
# 2     2016-03-27
# 3     2016-03-28
# 4     2016-03-29
#          ...
# 452   2016-04-08
# 453   2016-04-09
# 454   2016-04-10
# 455   2016-04-11
# 456   2016-04-12
# Name: ActivityDate, Length: 457, dtype: datetime64[ns]

# %%
unique_id = df.Id.unique()
print(unique_id)
# Out:
# [1503960366 1624580081 1644430081 1844505072 1927972279 2022484408
#  2026352035 2320127002 2347167796 2873212765 2891001357 3372868164
#  3977333714 4020332650 4057192912 4319703577 4388161847 4445114986
#  4558609924 4702921684 5553957443 5577150313 6117666160 6290855005
#  6391747486 6775888955 6962181067 7007744171 7086361926 8053475328
#  8253242879 8378563200 8583815059 8792009665 8877689391]

# %%
len(unique_id)
# Out:
# 35

# %%
df["Id"] == max(df["TotalDistance"])
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 452    True
# 453    True
# 454    True
# 455    True
# 456    True
# Name: Id, Length: 457, dtype: bool

# %%
df
# Out:
#             Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    27.530001    3/25/2016       11004       7.110000         7.110000
# 1    27.530001    3/26/2016       17609      11.550000        11.550000
# 2    27.530001    3/27/2016       12736       8.530000         8.530000
# 3    27.530001    3/28/2016       13231       8.930000         8.930000
# 4    27.530001    3/29/2016       12041       7.850000         7.850000
# ..         ...          ...         ...            ...              ...
# 452  27.530001     4/8/2016       23014      20.389999        20.389999
# 453  27.530001     4/9/2016       16470       8.070000         8.070000
# 454  27.530001    4/10/2016       28497      27.530001        27.530001
# 455  27.530001    4/11/2016       10622       8.060000         8.060000
# 456  27.530001    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df[df1["TotalDistance"] == max(df1["TotalDistance"])]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 454                       0.0               21.92                      1.12
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 454                 4.46                      0.0                128
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 454                   46                   211              1055      4526

# %%
df1[df1["VeryActiveDistance"] == max(df1["VeryActiveDistance"])]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 454                       0.0               21.92                      1.12
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 454                 4.46                      0.0                128
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 454                   46                   211              1055      4526

# %%
max(df1["TotalDistance"])
# Out:
# 27.5300006866455

# %%
mx = df1.nlargest(4, ["Id"])

# %%
print(mx)
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 445  8877689391     4/1/2016       18700      15.820000        15.820000
# 446  8877689391     4/2/2016       27572      23.389999        23.389999
# 447  8877689391     4/3/2016       15260       8.190000         8.190000
# 448  8877689391     4/4/2016       20779      18.410000        18.410000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 445                       0.0                8.70                      0.16
# 446                       0.0               14.72                      1.21
# 447                       0.0                1.80                      0.75
# 448                       0.0               11.73                      0.65
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 445                 6.91                     0.00                 67
# 446                 7.34                     0.01                116
# ...

# %%
three_l = df1.nlargest(3,["Calories"])

# %%
(three_l)
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 138  2891001357     4/1/2016           0       0.000000         0.000000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 304  5577150313     4/2/2016       14873      11.110000        11.110000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 138                  4.828032                0.00                      0.00
# 454                  0.000000               21.92                      1.12
# 304                  0.000000                8.19                      0.60
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 138                 0.00                      0.0                  0
# 454                 4.46                      0.0                128
# 304                 2.31                      0.0                202
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# ...

# %%
lowest_cal = df1.nsmallest(3,["Calories"])

# %%
lowest_cal
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 134  2873212765    4/12/2016           0            0.0              0.0
# 240  4319703577     4/9/2016           0            0.0              0.0
# 290  4702921684    4/12/2016           0            0.0              0.0
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 134                       0.0                 0.0                       0.0
# 240                       0.0                 0.0                       0.0
# 290                       0.0                 0.0                       0.0
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 134                  0.0                      0.0                  0
# 240                  0.0                      0.0                  0
# 290                  0.0                      0.0                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# ...

# %%
df1.sort_values(by=["Calories"])
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 412  8253242879    4/12/2016           0       0.000000         0.000000
# 134  2873212765    4/12/2016           0       0.000000         0.000000
# 323  6117666160    4/10/2016           0       0.000000         0.000000
# 290  4702921684    4/12/2016           0       0.000000         0.000000
# 240  4319703577     4/9/2016           0       0.000000         0.000000
# ..          ...          ...         ...            ...              ...
# 416  8378563200     4/4/2016       13935      11.050000        11.050000
# 347  6775888955     4/5/2016        9348       6.700000         6.700000
# 304  5577150313     4/2/2016       14873      11.110000        11.110000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 138  2891001357     4/1/2016           0       0.000000         0.000000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...
